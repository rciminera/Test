# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
import requests
import urllib.request
from pandas.io.json import json_normalize

# %%
# Import coins file as DataFrame
coins_messari_df = pd.read_csv("../Data_Notebooks/coin_symbols.csv")

# %%
# Add columns for sentiment
# Note that we used "" to specify initial entry.
coins_messari_df["sector"] = ""
coins_messari_df
# Out:
#     symbol            id sector
# 0      btc       bitcoin
# 1      eth      ethereum
# 2     usdt        tether
# 3      bnb   binancecoin
# 4      ada       cardano
# ..     ...           ...    ...
# 245    mln         melon
# 246   kobe   shabu-shabu
# 247    zmt  zipmex-token
# 248    rif     rif-token
# 249  cream       cream-2
#
# [250 rows x 3 columns]

# %%
base_url = "https://data.messari.io/api/v2/assets/"
# https://data.messari.io/api/v2/assets/{assetKey}/profile

base_url
# Out:
# 'https://data.messari.io/api/v2/assets/'

# %%
# symbol = "btc"

# %%
# url = f"{base_url}{symbol}/profile"
# url

# %%
# response = requests.get(url).json()

# %%
# response["data"]["profile"]["general"]["overview"]["sector"]

# %%
# Use the coins_df file to select symbol from sentiment data
for index, row in coins_messari_df.iterrows():
    # get coin symbol
    symbol = row["symbol"]

    # Use the search term: "Coin" and our symbol
    url = f"{base_url}{symbol}/profile"

    # make request and print url
    response = requests.get(url).json()
    

#     # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        coins_messari_df.loc[index,"sector"] = response["data"]["profile"]["general"]["overview"]["sector"]
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# ...

# %%
coins_messari_df.head(50)
# Out:
#    symbol                         id                             sector
# 0     btc                    bitcoin                         Currencies
# 1     eth                   ethereum           Smart Contract Platforms
# 2    usdt                     tether                        Stablecoins
# 3     bnb                binancecoin              Centralized Exchanges
# 4     ada                    cardano           Smart Contract Platforms
# 5     xrp                     ripple                         Currencies
# 6    doge                   dogecoin                         Currencies
# 7    usdc                   usd-coin                        Stablecoins
# 8     dot                   polkadot           Smart Contract Platforms
# 9     uni                    uniswap            Decentralized Exchanges
# 10   busd                binance-usd                        Stablecoins
# 11    bch               bitcoin-cash                         Currencies
# ...

# %%
coins_messari_df.describe()
# Out:
#        symbol      id sector
# count     250     250    249
# unique    248     250     15
# top       ton  oxygen
# freq        2       1    217

# %%
coins_messari_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   symbol  250 non-null    object
#  1   id      250 non-null    object
#  2   sector  249 non-null    object
# dtypes: object(3)
# memory usage: 6.0+ KB

# %%
coins_df.to_csv("lunar_crush.csv", index=False)
