# %%
import urllib.request
url = "https://api.lunarcrush.com/v2?data=assets&key=b9c27jge0ku5kvggiqykth&symbol=BTC"
# url = "https://api.lunarcrush.com/v2?data=assets&key=b9c27jge0ku5kvggiqykth"

print(urllib.request.urlopen(url).read())
# Out:
# b'{"config":{"data":"assets","symbol":"\'BTC\'"},"usage":{"day":18,"month":18},"data":[{"id":1,"name":"Bitcoin","symbol":"BTC","price":33535.11832232,"price_btc":1,"market_cap":628645538602,"percent_change_24h":-3.91,"percent_change_7d":-3.11,"percent_change_30d":-8.59,"volume_24h":40097774070.25,"max_supply":"21000000","timeSeries":[{"asset_id":1,"time":1625090400,"open":34828.46646911,"close":34903.749747,"high":34903.749747,"low":34740.44623073,"volume":1193790857.33,"market_cap":652935864192,"url_shares":1570,"unique_url_shares":931,"reddit_posts":91,"reddit_posts_score":218,"reddit_comments":205,"reddit_comments_score":563,"tweets":10971,"tweet_spam":3253,"tweet_followers":59145368,"tweet_quotes":229,"tweet_retweets":3039,"tweet_replies":1384,"tweet_favorites":18126,"tweet_sentiment1":639,"tweet_sentiment2":1199,"tweet_sentiment3":1299,"tweet_sentiment4":7266,"tweet_sentiment5":568,"tweet_sentiment_impact1":11768401,"tweet_sentiment_impact2":8210213,"tweet_sentiment_impact3":479
# ...

# %%
url = "https://api.lunarcrush.com/v2?data=market&key=b9c27jge0ku5kvggiqykth&desc=True"
print(urllib.request.urlopen(url).read())
# Out:
# b'{"config":{"data":"market","desc":"True","limit":0,"page":0,"total_rows":2220,"btc":{"id":1,"s":"BTC","n":"Bitcoin","p":33611.04262105,"p_btc":1,"v":39987758786.6,"vt":0.02137714728514743,"pc":-3.88,"pch":-0.08,"mc":628864369088,"gs":58.5,"ss":1327383107,"as":3.583333333333332,"bl":205246,"br":40641,"sp":110888,"na":470,"md":12,"t":287088,"r":4616,"yt":13,"sv":307273,"u":54329,"c":10878,"sd":30.09491343845201,"d":42.496629595438115,"cr":1.7,"acr":52,"timeSeries":[{"p":33545.10436285,"ss":66016999,"na":21,"ts":6698,"sv":17650,"u":2265},{"p":33368.73465847,"ss":72334107,"na":30,"ts":6610,"sv":14380,"u":2376},{"p":33141.39846304,"ss":68984572,"na":20,"ts":5147,"sv":12922,"u":2225},{"p":33452.34162694,"ss":83035536,"na":28,"ts":4662,"sv":11776,"u":2479},{"p":33544.45544481,"ss":65483503,"na":10,"ts":3900,"sv":13887,"u":2247},{"p":33565.43032263,"ss":57753553,"na":11,"ts":3437,"sv":11293,"u":1886}]}},"usage":{"day":17,"month":17},"data":[{"id":3397,"s":"CTK","n":"CertiK","p":1.20835443,
# ...

# %%
# df = pd.read_json('data/url.json')
df = pd.json_normalize(url)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-59e70f6a21dd> in <module>
#       1 # df = pd.read_json('data/url.json')
# ----> 2 df = pd.json_normalize(url)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     268
#     269     if record_path is None:
# --> 270         if any([isinstance(x, dict) for x in y.values()] for y in data):
#     271             # naive normalization, this is idempotent for flat records
#     272             # and potentially will inflate the data considerably for
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_normalize.py in <genexpr>(.0)
#     268
#     269     if record_path is None:
# --> 270         if any([isinstance(x, dict) for x in y.values()] for y in data):
# ...
