# %%
#  Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder
import pandas as pd
# import tensorflow as tf
import glob
import numpy as np
# import yfinance as yf
import plotly.graph_objs as go
import json
import re
import urllib.request

# %%
# Get 30, 200day, and 1 Year pricing changes from Coin Gecko
url= "https://api.coingecko.com/api/v3/coins/markets?vs_currency=USD&order=market_cap_desc&per_page=100&page=1&sparkline=false&price_change_percentage=30d%2C200d%2C1y"
df = pd.read_json(url)
df.head(50)
# Out:
#                       id    symbol               name  \
# 0                bitcoin       btc            Bitcoin
# 1               ethereum       eth           Ethereum
# 2                 tether      usdt             Tether
# 3            binancecoin       bnb       Binance Coin
# 4                cardano       ada            Cardano
# 5               dogecoin      doge           Dogecoin
# 6                 ripple       xrp                XRP
# 7               usd-coin      usdc           USD Coin
# 8               polkadot       dot           Polkadot
# 9            binance-usd      busd        Binance USD
# 10               uniswap       uni            Uniswap
# 11          bitcoin-cash       bch       Bitcoin Cash
# 12                solana       sol             Solana
# 13              litecoin       ltc           Litecoin
# 14             chainlink      link          Chainlink
# 15      ethereum-classic       etc   Ethereum Classic
# ...

# %%
count_df = df[df["price_change_percentage_1y_in_currency"] >= 0].count()
count_df
# Out:
# id                                          75
# symbol                                      75
# name                                        75
# image                                       75
# current_price                               75
# market_cap                                  75
# market_cap_rank                             75
# fully_diluted_valuation                     28
# total_volume                                75
# high_24h                                    75
# low_24h                                     75
# price_change_24h                            75
# price_change_percentage_24h                 75
# market_cap_change_24h                       75
# market_cap_change_percentage_24h            75
# circulating_supply                          75
# total_supply                                66
# max_supply                                  28
# ath                                         75
# ath_change_percentage                       75
# ...

# %%
count_df = df[df["price_change_percentage_200d_in_currency"] >= 0].count()
count_df
# Out:
# id                                          91
# symbol                                      91
# name                                        91
# image                                       91
# current_price                               91
# market_cap                                  91
# market_cap_rank                             91
# fully_diluted_valuation                     39
# total_volume                                91
# high_24h                                    91
# low_24h                                     91
# price_change_24h                            91
# price_change_percentage_24h                 91
# market_cap_change_24h                       91
# market_cap_change_percentage_24h            91
# circulating_supply                          91
# total_supply                                81
# max_supply                                  39
# ath                                         91
# ath_change_percentage                       91
# ...

# %%
count_df = df[df["price_change_percentage_30d_in_currency"] >= 0].count()
count_df
# Out:
# id                                          18
# symbol                                      18
# name                                        18
# image                                       18
# current_price                               18
# market_cap                                  18
# market_cap_rank                             18
# fully_diluted_valuation                      4
# total_volume                                18
# high_24h                                    18
# low_24h                                     18
# price_change_24h                            18
# price_change_percentage_24h                 18
# market_cap_change_24h                       18
# market_cap_change_percentage_24h            18
# circulating_supply                          18
# total_supply                                18
# max_supply                                   4
# ath                                         18
# ath_change_percentage                       18
# ...
